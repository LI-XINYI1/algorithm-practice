# %% [markdown]
# 209. Minimum Size Subarray Sum
#      Medium
#
# Given an array of positive integers nums and a positive integer target, return the minimal length of a
# subarray
# whose sum is greater than or equal to target. If there is no such subarray, return 0 instead.
#
# Example 1:
#
# Input: target = 7, nums = [2,3,1,2,4,3]
# Output: 2
# Explanation: The subarray [4,3] has the minimal length under the problem constraint.
# Example 2:
#
# Input: target = 4, nums = [1,4,4]
# Output: 1
# Example 3:
#
# Input: target

# %%
# |209. Minimum Size Subarray Sum|10.8|two pointers|m|py|
class Solution:
    def minSubArrayLen(self, target: int, nums: List[int]) -> int:
        left, right = 0, 1   # [left, right)
        cur = nums[0]
        length = 1
        rlt = float('inf')
        while left < len(nums):
            if cur < target:
                if right < len(nums):
                    length += 1
                    cur += nums[right]
                    right += 1
                else:
                    break
            else:
                rlt = length if length < rlt else rlt
                length -= 1
                cur -= nums[left]
                left += 1
        return rlt if rlt != float('inf') else 0

# %% [markdown]
# 815. Bus Routes
#      Hard
#
# You are given an array routes representing bus routes where routes[i] is a bus route that the ith bus repeats forever.
#
# For example, if routes[0] = [1, 5, 7], this means that the 0th bus travels in the sequence 1 -> 5 -> 7 -> 1 -> 5 -> 7 -> 1 -> ... forever.
# You will start at the bus stop source (You are not on any bus initially), and you want to go to the bus stop target. You can travel between bus stops by buses only.
#
# Return the least number of buses you must take to travel from source to target. Return -1 if it is not possible.
#
# Example 1:
#
# Input: routes = [[1,2,7],[3,6,7]], source = 1, target = 6
# Output: 2
# Explanation: The best strategy is take the first bus to the bus stop 7, then take the second bus to the bus stop 6.
# Example 2:
#
# Input: routes = [[7,12],[4,5,15],[6],[15,19],[9,12,13]], source = 15, target = 12
# Output: -1

# %%
# |815. Bus Routes|10.8|BFS|h|py|
class Solution:
    def numBusesToDestination(self, routes: List[List[int]], source: int, target: int) -> int:

        stopWithRoutes = collections.defaultdict(set)
        for busIndex, stops in enumerate(routes):
            for stop in stops:
                stopWithRoutes[stop].add(busIndex)

        que = [(source, 0)]  # (stop, busCount)
        visitedRoutes = set()
        visitedStops = set([source])

        for stop, counts in que:
            if stop == target:
                return counts
            for busIndex in stopWithRoutes[stop]:
                if busIndex not in visitedRoutes:
                    visitedRoutes.add(busIndex)
                    for nextStop in routes[busIndex]:
                        if nextStop not in visitedStops:
                            visitedStops.add(nextStop)
                            que.append((nextStop, counts+1))

        return -1

# %% [markdown]
# 23. Merge k Sorted Lists
#     Hard
#
# You are given an array of k linked-lists lists, each linked-list is sorted in ascending order.
#
# Merge all the linked-lists into one sorted linked-list and return it.
#
# Example 1:
#
# Input: lists = [[1,4,5],[1,3,4],[2,6]]
# Output: [1,1,2,3,4,4,5,6]
# Explanation: The linked-lists are:
# [
# 1->4->5,
# 1->3->4,
# 2->6
# ]
# merging them into one sorted list:
# 1->1->2->3->4->4->5->6
# Example 2:
#
# Input: lists = []
# Output: []
# Example 3:
#
# Input: lists = [[]]
# Output: []

# %%
# |23. Merge k Sorted Lists|10.10|mergesort, linkedlist|h|py|
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next


class Solution:
    def mergeKLists(self, lists: List[Optional[ListNode]]) -> Optional[ListNode]:
        if not lists:
            return None
        if len(lists) == 1:
            return lists[0]

        mid = len(lists)//2
        left = self.mergeKLists(lists[:mid])
        right = self.mergeKLists(lists[mid:])

        return self.merge(left, right)

    def merge(self, l1, l2):
        dummy = ListNode(0)
        cur = dummy
        while l1 and l2:
            if l1.val < l2.val:
                cur.next = l1
                l1 = l1.next
            else:
                cur.next = l2
                l2 = l2.next
            cur = cur.next
        cur.next = l1 or l2
        return dummy.next


class Solution:
    def mergeKLists(self, lists: List[Optional[ListNode]]) -> Optional[ListNode]:
        store = {}

        for lst in lists:
            start = lst
            while start:
                cur = start
                while cur.next and cur.next.val == start.val:
                    cur = cur.next
                try:
                    sect_head, sect_tail = store[start.val]
                except KeyError:
                    store[start.val] = [start, cur]
                else:
                    sect_tail.next = start
                    store[start.val][1] = cur
                start = cur.next

        tail = None
        head = None

        for key in sorted(store.keys()):
            front = store[key][0]
            if not tail:
                head = front
            else:
                tail.next = front
            tail = store[key][1]

        return head

# %% [markdown]
# 2046. Sort Linked List Already Sorted Using Absolute Values
#       Medium
#
# Given the head of a singly linked list that is sorted in non-decreasing order using the absolute values of its nodes, return the list sorted in non-decreasing order using the actual values of its nodes.
#
# Example 1:
# Input: head = [0,2,-5,5,10,-10]
# Output: [-10,-5,0,2,5,10]
# Explanation:
# The list sorted in non-descending order using the absolute values of the nodes is [0,2,-5,5,10,-10].
# The list sorted in non-descending order using the actual values is [-10,-5,0,2,5,10].
#
# Example 2:
# Input: head = [0,1,2]
# Output: [0,1,2]
# Explanation:
# The linked list is already sorted in non-decreasing order.
#
# Example 3:
# Input: head = [1]
# Output: [1]
# Explanation:
# The linked list is already sorted in non-decreasing order.

# %%
# |2046. Sort Linked List Already Sorted Using Absolute Values|10.10|linkedlist|m|py|

# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def sortLinkedList(self, head: Optional[ListNode]) -> Optional[ListNode]:
        prev = head
        cur = head.next
        while cur:
            next_node = cur.next  # MUST
            if cur.val < 0:
                prev.next = cur.next
                cur.next = head
                head = cur
            else:
                prev = prev.next
            # cur = cur.next  # cur was updated
            cur = next_node
        return head

# %% [markdown]
# 5. Longest Palindromic Substring
#    Medium
#
# Given a string s, return the longest palindromic substring in s.
#
# Example 1:
# Input: s = "babad"
# Output: "bab"
# Explanation: "aba" is also a valid answer.
#
# Example 2:
# Input: s = "cbbd"
# Output: "bb"

# %%
class Solution:
    def longestPalindrome(self, s: str) -> str:
        n = len(s)
        dp = [[False] * n for _ in range(n)]
        res = s[0]
        for i in range(n):
            dp[i][i] = True
        for i in range(n-1, -1, -1):
            for j in range(i+1, n):
                if s[i] == s[j] and (j-i < 3 or dp[i+1][j-1]):
                    dp[i][j] = True
                if dp[i][j] and j-i+1 > len(res):
                    res = s[i:j+1]
        return res

# %% [markdown]
# 253. Meeting Rooms II
#      Medium
#      Given an array of meeting time intervals intervals where intervals[i] = [starti, endi], return the minimum number of conference rooms required.
#
# Example 1:
# Input: intervals = [[0,30],[5,10],[15,20]]
# Output: 2
#
# Example 2:
# Input: intervals = [[7,10],[2,4]]
# Output: 1

# %%
# 1. heap / priority queue
# 2. two pointer, 类似前缀和？？？

import heapq
from queue import PriorityQueue

class Solution:
  def minRoom(self, intervals: List[List[int]]) -> int:
    if not intervals:
      return 0
    intervals.sort(key = lambda x:x[0])

    heap = [] # 1. heap
    # array = [] 
    # heapq.heapify(array)

    pq = PriorityQueue() # 2. priority queue

    res = 0
    for interval in intervals:
      if not heap or interval[0] < pq[0]:
        res += 1
      else:
        heapq.heappop(heap)
        # minval = pq.queue[0] # or pq.get()
        # pq.remove((minval,minval))

      heapq.heappush(heap,interval[1])
      # pq.put((interval[1],interval[1])) #(key,val)
    return res


class Solution:
  def minRoom(self, intervals: List[List[int]]) -> int:
    num = len(intervals)
    startT, endT = [], []
    for interval in intervals:
      startT.append(interval[0])
      endT.append(interval[1])
    startT.sort()
    endT.sort()
    
    activate = 0
    res = 0

    # two pointers
    i, j = 0, 0
    while i<num and j < num:
      if startT[i] < endT[j]:
        activate += 1
        i += 1
      else:
        activate -= 1
        j += 1
      res = max(res,activate)
    
    return res
